# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
with open('Tromis-20190107_150250.log') as csvfp1:
    reader = csv.reader(csvfp1, delimiter=',')
    header = next(reader)
    data1 = [r for r in reader]
with open('Tromis-20190107_202109.log') as csvfp2:   
    reader = csv.reader(csvfp2, delimiter=',')
    header = next(reader)
    data2 = [r for r in reader]

print header
epoch = [int(d[0]) for d in data1+data2[1:]]
loss = [float(d[2]) for d in data1+data2[1:]]
win = [float(d[3][:-1]) for d in data1+data2[1:]]
avgscore = [float(d[4]) for d in data1+data2[1:]]
maxscore = [float(d[5]) for d in data1+data2[1:]]
# Out:
# ['Epoch', ' Epsilon', '    Loss', ' Win Ratio', ' Avg Score', ' Max Score', '   Memory']

# %%
plt.plot(epoch, loss)
plt.show()
